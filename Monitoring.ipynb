# %%
import requests
def telegram_bot_sendtext(bot_message):
    bot_token = '7077738335:AAHdZMrX8QRuAHbY_Hj9FMjNQsKCa12E--w'
    bot_chatID = '6638573028'
    send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + bot_chatID + '&parse_mode=Markdown&text=' + bot_message+ bot_message
    response = requests.get(send_text)
    return response.json()

# %%
telegram_bot_sendtext('Testing_message')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...
